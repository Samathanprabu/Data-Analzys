# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
titanic.plot(figsize = (10,12))
plt.show()

# %%
titanic['survived'].plot(kind = 'bar')
plt.show()
#matplotlib.pyplot.show()

# %%
titanic['age'].plot(kind = 'hist', figsize = (20,30))

# %%
#figsize is the figuresize(width,height)
titanic.plot(subplots = True, figsize = (10,12))
plt.show()

# %%
titanic.plot(subplots = True, figsize = (12,10), sharex = False)
plt.show()

# %%
titanic.plot(subplots = True, figsize = (12,10), sharex = False, sharey = True, color = ['green','red','yellow','orange','black','blue'])
plt.show()

# %%
titanic.age.plot(figsize = (8,6), kind = 'line', fontsize = 20)
plt.show()

# %%
titanic.age.plot(figsize = (8,5), kind = 'line', fontsize = 15, color = 'green',linestyle = ':')
plt.show()

# %%
titanic.age.plot(figsize = (12,10), kind = 'line', fontsize = 13, color = 'black', linestyle = 'dotted' )
plt.title('Distribution of Ages',fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Distribution of Ages')

# %%
titanic.age.plot(figsize = (12,10), kind = 'line', fontsize = 20, color = 'black', linestyle = 'dotted', title = 'Age Distribution' )

# %%
titanic.age.plot(figsize = (8,5), kind = 'line', fontsize = 13, color = 'red', linestyle = ':' )
plt.title('Distribution of Ages',fontsize = 15)
plt.legend()

# %%
titanic.age.plot(figsize = (8,5), kind = 'line', fontsize = 13, color = 'black', linestyle = ':' )
plt.title('Distribution of Ages',fontsize = 15)
plt.legend(loc =9 , fontsize = 18)

# %%
titanic.age.plot(figsize = (8,5), kind = 'line', fontsize = 19, color = 'blue', linestyle = ':' )
plt.title('Distribution of Ages',fontsize = 22)
plt.legend(loc = 3, fontsize = 10)
plt.xlabel('Frequency', fontsize = 22)
plt.ylabel('Age', fontsize = 22)
# Out:
# Text(0, 0.5, 'Age')

# %%
titanic.age.plot(figsize = (8,5), kind = 'line', fontsize = 13, color = 'black', linestyle = ':' )
plt.title('Distribution of Ages',fontsize = 15)
plt.legend(loc = 3, fontsize = 18)
plt.xlabel('Frequency', fontsize = 15)
plt.ylabel('Age', fontsize = 15)
plt.grid()

# %%
titanic.age.plot(figsize = (8,5), kind = 'line', fontsize = 13, color = 'black', linestyle = ':', xlim= (100,300))
plt.title('Distribution of Ages',fontsize = 15)
plt.legend(loc = 3, fontsize = 18)
plt.xlabel('Frequency', fontsize = 15)
plt.ylabel('Age', fontsize = 15)
plt.grid()

# %%
titanic.age.plot(figsize = (8,5), kind = 'line', fontsize = 13, color = 'black', linestyle = ':', xlim= (100,300), ylim = (30,60))
plt.title('Distribution of Ages',fontsize = 15)
plt.legend(loc = 3, fontsize = 18)
plt.xlabel('Frequency', fontsize = 15)
plt.ylabel('Age', fontsize = 15)
plt.grid()

# %%
xticks = [i for i in range(0,901,50)]

# %%
yticks = [i for i in range(0,81,5)]

# %%
titanic.age.plot(figsize = (12,5), kind = 'line', fontsize = 13, color = 'black', linestyle = ':', 
                 xticks = xticks, yticks = yticks)
plt.title('Distribution of Ages',fontsize = 15)
plt.legend(loc = 3, fontsize = 18)
plt.xlabel('Frequency', fontsize = 15)
plt.ylabel('Age', fontsize = 15)
plt.grid()

# %%
titanic.age.plot(figsize = (12,5), kind = 'line', fontsize = 13, color = 'black', linestyle = ':', 
                 xlim= (0,900), ylim = (0,80), xticks = xticks, yticks = yticks)
plt.title('Distribution of Ages',fontsize = 15)
plt.legend(loc = 3, fontsize = 18)
plt.xlabel('Frequency', fontsize = 15)
plt.ylabel('Age', fontsize = 15)
plt.grid()

# %%
titanic.age.plot(figsize = (12,5), kind = 'line', fontsize = 13, color = 'black', linestyle = ':', 
                 xlim= (0,900), ylim = (0,80),yticks = yticks, rot = 45)
plt.title('Distribution of Ages',fontsize = 15)
plt.legend(loc = 3, fontsize = 18)
plt.xlabel('Frequency', fontsize = 15)
plt.ylabel('Age', fontsize = 15)
plt.grid()

# %%
plt.style.available
# Out:
# ['seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-ticks',
#  'fivethirtyeight',
#  'seaborn-whitegrid',
#  'classic',
#  '_classic_test',
#  'fast',
#  'seaborn-talk',
#  'seaborn-dark-palette',
#  'seaborn-bright',
#  'seaborn-pastel',
#  'grayscale',
#  'seaborn-notebook',
#  'ggplot',
#  'seaborn-colorblind',
#  'seaborn-muted',
#  'seaborn',
#  'Solarize_Light2',
#  'seaborn-paper',
#  'bmh',
#  'tableau-colorblind10',
#  'seaborn-white',
#  'dark_background',
#  'seaborn-poster',
#  'seaborn-deep']

# %%
plt.style.use('dark_background')

# %%
titanic.age.plot(figsize = (12,5), kind = 'line', fontsize = 13, color = 'red', linestyle = ':', 
                 xlim= (0,900), ylim = (0,80), xticks = xticks, yticks = yticks, rot = 45)
plt.title('Distribution of Ages',fontsize = 15)
plt.legend(loc = 3, fontsize = 18)
plt.xlabel('Frequency', fontsize = 15)
plt.ylabel('Age', fontsize = 15)
# Out:
# Text(0, 0.5, 'Age')

# %%
titanic.age.plot(figsize = (12,5), kind = 'line', fontsize = 13, color = 'black', linestyle = ':', 
                 xlim= (0,900), ylim = (0,80), xticks = xticks, yticks = yticks, rot = 90)
plt.title('Distribution of Ages',fontsize = 15)
plt.legend(loc = 3, fontsize = 18)
plt.xlabel('Frequency', fontsize = 15)
plt.ylabel('Age', fontsize = 15)
plt.grid()

# %%
plt.style.use('classic')

# %%
titanic.age.plot(figsize = (12,5), kind = 'line', fontsize = 13, color = 'black', linestyle = ':', 
                 xlim= (0,900), ylim = (0,80), xticks = xticks, yticks = yticks, rot = 90)
plt.title('Distribution of Ages',fontsize = 15)
plt.legend(loc = 3, fontsize = 18)
plt.xlabel('Frequency', fontsize = 15)
plt.ylabel('Age', fontsize = 15)
plt.grid()

# %%
titanic.age.value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
#          ..
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: age, Length: 88, dtype: int64

# %%
titanic.age.value_counts(bins = 5)
# Out:
# (16.336, 32.252]    346
# (32.252, 48.168]    188
# (0.339, 16.336]     100
# (48.168, 64.084]     69
# (64.084, 80.0]       11
# Name: age, dtype: int64

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
# survived    891 non-null int64
# pclass      891 non-null int64
# sex         891 non-null object
# age         714 non-null float64
# sibsp       891 non-null int64
# parch       891 non-null int64
# fare        891 non-null float64
# embarked    889 non-null object
# deck        203 non-null object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.age.plot(kind = 'hist', figsize = (12,4),fontsize = 12)

# %%
titanic.age.plot(kind = 'hist', figsize = (12,4),fontsize = 12, color = 'red', bins = 20)

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
x = titanic[titanic["age"]<28]

# %%
x
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 7           0       3    male   2.0      3      1  21.0750        S  NaN
# 8           1       3  female  27.0      0      2  11.1333        S  NaN
# 9           1       2  female  14.0      1      0  30.0708        C  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 882         0       3  female  22.0      0      0  10.5167        S  NaN
# 884         0       3    male  25.0      0      0   7.0500        S  NaN
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 889         1       1    male  26.0      0      0  30.0000        C    C
#
# [337 rows x 9 columns]

# %%
x.mean()
# Out:
# survived     0.458101
# pclass       2.569832
# age         12.651788
# sibsp        1.039106
# parch        0.759777
# fare        29.853074
# dtype: float64

# %%
x.mode()
# Out:
#    survived  pclass   sex   age  sibsp  parch   fare embarked deck
# 0       0.0     3.0  male  18.0    0.0    0.0   8.05        S    B
# 1       NaN     NaN   NaN   NaN    NaN    NaN  26.00      NaN  NaN

# %%
titanic.age.plot(kind = 'box')

# %%
titanic.loc[titanic['sex']=='female']
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 8           1       3  female  27.0      0      2  11.1333        S  NaN
# 9           1       2  female  14.0      1      0  30.0708        C  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 880         1       2  female  25.0      0      1  26.0000        S  NaN
# 882         0       3  female  22.0      0      0  10.5167        S  NaN
# 885         0       3  female  39.0      0      5  29.1250        Q  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [314 rows x 9 columns]

# %%
titanic.age.plot(kind = 'barh', figsize = (18,12))

# %%
titanic.age.plot(kind = 'hist', figsize = (12,5),fontsize = 12, bins = 5, color = 'red', density = True)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
pclass = titanic.groupby(by = 'pclass')['pclass'].count()

# %%
pclass
# Out:
# pclass
# 1    216
# 2    184
# 3    491
# Name: pclass, dtype: int64

# %%
plt.pie(pclass, labels = ['Class1','Class2','Class3'],autopct='%1.1f%%', radius = 4, explode =(.4,.1,.4))
# Out:
# ([<matplotlib.patches.Wedge at 0x7fba3814dfd0>,
# ...
#  [Text(3.473923307721954, 3.31237933396315, 'Class1'),
#   Text(-2.545231173469125, 3.711037358152163, 'Class2'),
#   Text(-0.7667610127709281, -4.738362327776814, 'Class3')],
#  [Text(2.026455262837806, 1.9322212781451709, '24.2%'),
#   Text(-1.414017318593958, 2.061687421195646, '20.7%'),
#   Text(-0.44727725744970803, -2.764044691203141, '55.1%')])

# %%
# In order to save the file you can save the same in the variable and make use of savefig function

plt.savefig('classdistribution.jpeg')

# %%
gender = titanic.groupby(by = 'sex')['sex'].count()

# %%
gender
# Out:
# sex
# female    314
# male      577
# Name: sex, dtype: int64

# %%
explode = (0, 0.3, 0.2)

# %%
plt.pie(gender, labels = ['Male','Female'], autopct='%1.1f%%', colors = ['red', 'yellow'], explode = explode )
# Out:
# ([<matplotlib.patches.Wedge at 0x7f82bd1336d0>,
# ...
#  [Text(0.4919453215643337, 0.9838647267744507, 'Male'),
#   Text(-0.6261121102068867, -1.2521915290610615, 'Female')],
#  [Text(0.2683338117623638, 0.5366534873315185, '35.2%'),
#   Text(-0.4025006422758557, -0.8049802686821108, '64.8%')])

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
import pandas as pd

# %%
titanic.to_csv('/Users/mdarifmokhtar/Desktop/Desktop Stuff/Docs/titanic_updated.csv')

# %%
embarkation = titanic.groupby(by = 'embarked')['embarked'].count()

# %%
embarkation
# Out:
# embarked
# C    168
# Q     77
# S    644
# Name: embarked, dtype: int64

# %%
plt.pie(embarkation, labels = ['Cherbourg','Queenstown','Southampton'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fb9f43f6510>,
# ...
#  [Text(0.911772230064993, 0.6153628201982223, 'Cherbourg'),
#   Text(0.12219517070335402, 1.0931918131127667, 'Queenstown'),
#   Text(-0.7128397429902672, -0.8377705537995294, 'Southampton')],
#  [Text(0.49733030730817795, 0.3356524473808485, '18.9%'),
#   Text(0.06665191129273855, 0.5962864435160545, '8.7%'),
#   Text(-0.38882167799469114, -0.45696575661792505, '72.4%')])

# %%
survival = titanic.groupby('sex')titanic['survived'].count()
# Out:
#   File "<ipython-input-90-b9639459a8cb>", line 1
#     survival = titanic.groupby('sex')titanic['survived']==1.count()
#                                            ^
# SyntaxError: invalid syntax

# %%
survival=titanic[((titanic['sex']=='female')|(titanic['sex']=='male')) &(titanic['survived']==1)]

# %%
survival
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 8           1       3  female  27.0      0      2  11.1333        S  NaN
# 9           1       2  female  14.0      1      0  30.0708        C  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 875         1       3  female  15.0      0      0   7.2250        C  NaN
# 879         1       1  female  56.0      0      1  83.1583        C    C
# 880         1       2  female  25.0      0      1  26.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 889         1       1    male  26.0      0      0  30.0000        C    C
#
# [342 rows x 9 columns]

# %%
x = survival.groupby('sex')['survived'].count()

# %%
x
# Out:
# sex
# female    233
# male      109
# Name: survived, dtype: int64

# %%
y = titanic[(titanic['sex']=='female') & (titanic['survived']==1)]

# %%
survival
# Out:
# sex
# female    314
# male      577
# Name: survived, dtype: int64

# %%
plt.pie(x, labels = ['Female','Male'],autopct='%1.1f%%', colors = ['orange','green'], radius = 5)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fba194e5910>,
# ...
#  [Text(-2.9657929898557467, 4.631854050088637, 'Female'),
#   Text(2.9657934235212084, -4.631853772411036, 'Male')],
#  [Text(-1.6177052671940437, 2.526465845502893, '68.1%'),
#   Text(1.617705503738841, -2.5264656940423835, '31.9%')])

# %%
summer2012 = pd.read_csv('summer_2012.csv', index_col = 'Country')

# %%
summer2012.head()
# Out:
#          Medal
# Country
# USA        250
# RUS        130
# CHN        128
# GBR        126
# AUS        114

# %%
summer2012.Medal.plot(kind= 'line')

# %%
summer2012.Medal.plot(kind= 'bar', figsize = (10,8), fontsize = 11)

# %%
summer2012.Medal.plot(kind= 'barh', figsize = (10,8), fontsize = 11)

# %%
summer2012.Medal.plot(kind= 'pie', figsize = (10,8), fontsize = 11)

# %%
titanic.plot(x = 'age',y = 'fare',kind='scatter', figsize = (15,8), marker = 'D', s= 25)

# %%
titanic.plot(x = 'age',y = 'fare',kind='scatter', figsize = (15,8), c = 'survived',marker = 'D', s = 50, colormap = 'viridis')

# %%
titanic.plot(x = 'age',y = 'fare',kind='scatter', figsize = (15,8), c = 'pclass',marker = 'D', s = 50, colormap = 'viridis')

# %%
year = [1972, 1982, 1992, 2002, 2012]
e_india = [100.6, 158.61, 305.54, 394.96, 724.79]
e_bangladesh = [10.5, 25.21, 58.65, 119.27, 274.87]

# %%
plt.plot(year, e_india, color ='orange', 
         label ='India')
  
plt.plot(year, e_bangladesh, color ='g', 
         label ='Bangladesh')

plt.legend()
